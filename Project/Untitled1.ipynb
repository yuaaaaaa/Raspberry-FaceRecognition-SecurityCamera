# %%
import sys
import os
import importlib
import cv2
import tkinter as tk
import tkinter.messagebox
from tkinter import filedialog
import tkinter,datetime
############################################################################################
#功能描述
##############################################################################################3
# 打开文件夹
def open_familyNumber():
    path = os.getcwd()+'\\face_dataset'
    os.startfile(path)

# 打开存录视频文件夹
def open_video():
    path = os.getcwd()+'\\video'
    os.startfile(path)
    
# 开启设备
def open_camera():
    import os
    os.system('final.py')
    
# 摔倒检测
def fall():
    import os
    os.system('Falldetection\\Fall_down.py')
################################################################################################
# 界面描述
###################################################################################################
importlib.reload(sys)

def uptime():
    global TimeLabel
    TimeLabel["text"] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S:') + "%d" %(datetime.datetime.now().microsecond // 100000)
    win.after(100,uptime)

window = tk.Tk()
window.geometry('350x600+200+10')
window.title('人脸识别小程序')

fm1 = tk.Frame(window)
fm21 = tk.Frame(window)
fm22 = tk.Frame(window)
fm3 = tk.Frame(window)

Ltop1=tk.Label(fm1,text="wifi", bg='white',anchor="nw")
Ltop2=tk.Label(fm1,text="12:00", bg='white')
Ltop=tk.Label(fm1,text = "%s%d" %(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S:'),datetime.datetime.now().microsecond // 100000))
B1=tk.Button(fm21, text = "点我启动",command = open_camera)
B2=tk.Button(fm21, text = "家庭成员",command = open_familyNumber)
B3=tk.Button(fm22, text = "摔倒检测",command = fall )
B4=tk.Button(fm22, text = "存录视频",command = open_video)
Lbot=tk.Label(fm3,text="")

Ltop1.pack(side = tk.LEFT)
Ltop2.pack(side = tk.RIGHT)
Ltop.pack()
B1.pack(side=tk.LEFT)
B2.pack(side=tk.LEFT)
B3.pack(side=tk.LEFT)
B4.pack(side=tk.RIGHT)
Lbot.pack(side = tk.BOTTOM)

window.after(100,uptime)

fm1.pack(side=tk.TOP)
fm21.pack(side=tk.TOP)
fm22.pack(side=tk.TOP)
fm3.pack(side=tk.TOP)
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 749, in callit
#     func(*args)
#   File "<ipython-input-1-bd80c2b1cdda>", line 38, in uptime
#     TimeLabel["text"] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S:') + "%d" %(datetime.datetime.now().microsecond // 100000)
# NameError: name 'TimeLabel' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-bd80c2b1cdda>", line 20, in open_video
#     os.startfile(path)
# FileNotFoundError: [WinError 2] 系统找不到指定的文件。: 'E:\\jupyter notebook\\新建文件夹\\Raspberry-FaceRecognition-SecurityCamera\\Project\\video'
# Exception in Tkinter callback
# ...

# %%
import tkinter,datetime
def uptime():
    global TimeLabel
    TimeLabel["text"] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S:') + "%d" %(datetime.datetime.now().microsecond // 100000)
    win.after(100,uptime)
win = tkinter.Tk()
win.geometry("%dx%d" %(200,50))
TimeLabel = tkinter.Label(text = "%s%d" %(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S:'),datetime.datetime.now().microsecond // 100000))
TimeLabel.pack(padx = 10,pady = 8)
win.after(100,uptime)
win.mainloop()
